# %% [markdown]
# # OPL Data Exploration #
#
# The purpose of this notebook is to practice using and to explore the OPL bulk dataset

# %%
import pandas as pd
import requests
import zipfile
import io
import re

# OPL dataset location
url_OPL = "https://openpowerlifting.gitlab.io/opl-csv/files/openpowerlifting-latest.zip"

# GET request
response_OPL = requests.get(url_OPL)

# unzip if successful
if response_OPL.status_code == 200:
    with zipfile.ZipFile(io.BytesIO(response_OPL.content)) as z:
        # get all file names in zip
        file_list = z.namelist()

        # define expected filename
        file_name_pattern = re.compile(r"openpowerlifting-\d{4}-\d{2}-\d{2}\/openpowerlifting-\d{4}-\d{2}-\d{2}-.{8}\.csv")

        # find first matching file
        csv_OPL = None
        for file in file_list:
            if file_name_pattern.match(file):
                csv_OPL = file
                break

        if csv_OPL == None:
            print("Could not find desired csv file in returned zip file.")
        
        # open file and import to df
        with z.open(csv_OPL) as f:
            df = pd.read_csv(f)
    
    print("CSV file downloaded and imported to dataframe successfully.")
    print("DataFrame shape: ", df.shape)
else:
    print("Failed to download OPL csv, response code: ", response_OPL.status_code)
# Out:
# C:\Users\rjmm1\AppData\Local\Temp\ipykernel_18144\2725760971.py:34: DtypeWarning: Columns (31,33,35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f)
# CSV file downloaded and imported to dataframe successfully.
# DataFrame shape:  (3085139, 42)

# %%
df.head()
# Out:
#                      Name Sex Event Equipment   Age AgeClass BirthYearClass  \
# 0             Alona Vladi   F   SBD       Raw  33.0    24-34          24-39
# 1      Galina Solovyanova   F   SBD       Raw  43.0    40-44          40-49
# 2          Daniil Voronin   M   SBD       Raw  15.5    16-17          14-18
# 3          Aleksey Krasov   M   SBD       Raw  35.0    35-39          24-39
# 4  Margarita Pleschenkova   M   SBD       Raw  26.5    24-34          24-39
#
#   Division  BodyweightKg WeightClassKg  ...  Country  State  Federation  \
# 0        O         58.30            60  ...   Russia    NaN         GFP
# 1       M1         73.10            75  ...   Russia    NaN         GFP
# 2        T         67.40            75  ...   Russia    NaN         GFP
# 3        O         66.65            75  ...   Russia    NaN         GFP
# 4        O         72.45            75  ...   Russia    NaN         GFP
#
#    ParentFederation        Date  MeetCountry  MeetState  MeetTown  \
# ...
